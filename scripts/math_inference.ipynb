# %%
import numpy
import pandas as pd

import sympy
### similar to mathematica

from sympy import Symbol
from sympy.vector import CoordSys3D
from sympy import MatrixSymbol
from sympy.vector import Vector
from sympy import Point3D, Line3D
from sympy import symbols
from sympy import separatevars

# %%
sympy.init_printing(use_latex=True)

# %%
coodr = CoordSys3D('coodr')

ps_x, ps_y, ps_z = symbols('ps_x ps_y ps_z')
vs_x, vs_y, vs_z = symbols('vs_x vs_y vs_z')
point_s = Point3D(ps_x, ps_y, ps_z)
vec_s = vs_x * coodr.i + vs_y * coodr.j + vs_z * coodr.k

pt_x, pt_y, pt_z = symbols('pt_x pt_y pt_z')
vt_x, vt_y, vt_z = symbols('vt_x vt_y vt_z')
point_t = Point3D(pt_x, pt_y, pt_z)
vec_t = vt_x * coodr.i + vt_y * coodr.j + vt_z * coodr.k

radius = sympy.Symbol('radius')

# %%
pm_x, pm_y, pm_z = symbols('pm_x pm_y pm_z')
point_m = Point3D(pm_x, pm_y, pm_z)

# %%
vec_sm = (point_m.x - point_s.x) * coodr.i + \
    (point_m.y - point_s.y) * coodr.j + \
    (point_m.z - point_s.z) * coodr.k
norm_sm = vec_sm.cross(vec_s)

vec_tm = (point_m.x - point_t.x) * coodr.i + \
    (point_m.y - point_t.y) * coodr.j + \
    (point_m.z - point_t.z) * coodr.k
norm_tm = vec_tm.cross(vec_t)

vec_m = (norm_sm.cross(norm_tm)).normalize()

# %%
length_ms = sympy.sqrt(vec_sm.dot(vec_sm) - (-vec_sm).dot(vec_m))
length_mt = sympy.sqrt(vec_tm.dot(vec_tm) - (-vec_tm).dot(vec_m))

# %%
expr1 = sympy.Equality(length_ms, radius)
expr2 = sympy.Equality(length_mt, radius)

r = sympy.solve([expr1, expr2], [pm_x, pm_y, pm_z], dict=True)
r
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# d:\ProgramData\Anaconda3\lib\site-packages\sympy\core\assumptions.py in getit(self)
#     478         try:
# --> 479             return self._assumptions[fact]
#     480         except KeyError:
#
# KeyError: 'zero'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# d:\ProgramData\Anaconda3\lib\site-packages\sympy\core\assumptions.py in getit(self)
#     478         try:
# --> 479             return self._assumptions[fact]
#     480         except KeyError:
#
# KeyError: 'integer'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# d:\ProgramData\Anaconda3\lib\site-packages\sympy\core\assumptions.py in getit(self)
#     478         try:
# --> 479             return self._assumptions[fact]
#     480         except KeyError:
#
# KeyError: 'finite'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12896\1568631675.py in <module>
#       2 expr2 = sympy.Equality(length_mt, radius)
#       3
# ----> 4 r = sympy.solve([expr1, expr2], [pm_x, pm_y, pm_z], dict=True)
#       5 r
#
# d:\ProgramData\Anaconda3\lib\site-packages\sympy\solvers\solvers.py in solve(f, *symbols, **flags)
#    1106         solution = _solve(f[0], *symbols, **flags)
#    1107     else:
# -> 1108         solution = _solve_system(f, symbols, **flags)
#    1109
#    1110     #
#
# d:\ProgramData\Anaconda3\lib\site-packages\sympy\solvers\solvers.py in _solve_system(exprs, symbols, **flags)
#    1942                 for s in ok_syms:
#    1943                     try:
# -> 1944                         soln = _solve(eq2, s, **flags)
#    1945                     except NotImplementedError:
#    1946                         continue
#
# d:\ProgramData\Anaconda3\lib\site-packages\sympy\solvers\solvers.py in _solve(f, *symbols, **flags)
#    1695                 else:
#    1696                     try:
# -> 1697                         rv = set(_solve(eq, symbol, **flags))
#    1698                     except NotImplementedError:
#    1699                         rv = None
#
# d:\ProgramData\Anaconda3\lib\site-packages\sympy\solvers\solvers.py in _solve(f, *symbols, **flags)
#    1447         # first see if it really depends on symbol and whether there
#    1448         # is only a linear solution
# -> 1449         f_num, sol = solve_linear(f, symbols=symbols)
#    1450         if f_num.is_zero or sol is S.NaN:
#    1451             return []
#
# d:\ProgramData\Anaconda3\lib\site-packages\sympy\solvers\solvers.py in solve_linear(lhs, rhs, symbols, exclude)
#    2155             derivs[xi] = {der: der.doit() for der in derivs[xi]}
#    2156         newn = n.subs(derivs[xi])
# -> 2157         dnewn_dxi = newn.diff(xi)
#    2158         # dnewn_dxi can be nonzero if it survives differentation by any
#    2159         # of its free symbols
#
# d:\ProgramData\Anaconda3\lib\site-packages\sympy\core\expr.py in diff(self, *symbols, **assumptions)
#    3526     def diff(self, *symbols, **assumptions):
#    3527         assumptions.setdefault("evaluate", True)
# -> 3528         return _derivative_dispatch(self, *symbols, **assumptions)
#    3529
#    3530     ###########################################################################
#
# d:\ProgramData\Anaconda3\lib\site-packages\sympy\core\function.py in _derivative_dispatch(expr, *variables, **kwargs)
#    1921         from sympy.tensor.array.array_derivatives import ArrayDerivative
#    1922         return ArrayDerivative(expr, *variables, **kwargs)
# -> 1923     return Derivative(expr, *variables, **kwargs)
#    1924
#    1925
#
# d:\ProgramData\Anaconda3\lib\site-packages\sympy\core\function.py in __new__(cls, expr, *variables, **kwargs)
#    1449                     expr *= old_v.diff(old_v)
#    1450
# -> 1451             obj = cls._dispatch_eval_derivative_n_times(expr, v, count)
#    1452             if obj is not None and obj.is_zero:
#    1453                 return obj
#
# d:\ProgramData\Anaconda3\lib\site-packages\sympy\core\function.py in _dispatch_eval_derivative_n_times(cls, expr, v, count)
#    1910         # object, the default in `Basic` will call a loop over
#    1911         # `_eval_derivative`:
# -> 1912         return expr._eval_derivative_n_times(v, count)
#    1913
#    1914
#
# d:\ProgramData\Anaconda3\lib\site-packages\sympy\core\basic.py in _eval_derivative_n_times(self, s, n)
#    1779             obj = self
#    1780             for i in range(n):
# -> 1781                 obj2 = obj._eval_derivative(s)
#    1782                 if obj == obj2 or obj2 is None:
#    1783                     break
#
# d:\ProgramData\Anaconda3\lib\site-packages\sympy\core\cache.py in wrapper(*args, **kwargs)
#      68         def wrapper(*args, **kwargs):
#      69             try:
# ---> 70                 retval = cfunc(*args, **kwargs)
#      71             except TypeError as e:
#      72                 if not e.args or not e.args[0].startswith('unhashable type:'):
#
# d:\ProgramData\Anaconda3\lib\site-packages\sympy\core\add.py in _eval_derivative(self, s)
#     537     @cacheit
#     538     def _eval_derivative(self, s):
# --> 539         return self.func(*[a.diff(s) for a in self.args])
#     540
#     541     def _eval_nseries(self, x, n, logx, cdir=0):
#
# d:\ProgramData\Anaconda3\lib\site-packages\sympy\core\add.py in <listcomp>(.0)
#     537     @cacheit
#     538     def _eval_derivative(self, s):
# --> 539         return self.func(*[a.diff(s) for a in self.args])
#     540
#     541     def _eval_nseries(self, x, n, logx, cdir=0):
#
# d:\ProgramData\Anaconda3\lib\site-packages\sympy\core\expr.py in diff(self, *symbols, **assumptions)
#    3526     def diff(self, *symbols, **assumptions):
#    3527         assumptions.setdefault("evaluate", True)
# -> 3528         return _derivative_dispatch(self, *symbols, **assumptions)
#    3529
#    3530     ###########################################################################
#
# d:\ProgramData\Anaconda3\lib\site-packages\sympy\core\function.py in _derivative_dispatch(expr, *variables, **kwargs)
#    1921         from sympy.tensor.array.array_derivatives import ArrayDerivative
#    1922         return ArrayDerivative(expr, *variables, **kwargs)
# -> 1923     return Derivative(expr, *variables, **kwargs)
#    1924
#    1925
#
# d:\ProgramData\Anaconda3\lib\site-packages\sympy\core\function.py in __new__(cls, expr, *variables, **kwargs)
#    1449                     expr *= old_v.diff(old_v)
#    1450
# -> 1451             obj = cls._dispatch_eval_derivative_n_times(expr, v, count)
#    1452             if obj is not None and obj.is_zero:
#    1453                 return obj
#
# d:\ProgramData\Anaconda3\lib\site-packages\sympy\core\function.py in _dispatch_eval_derivative_n_times(cls, expr, v, count)
#    1910         # object, the default in `Basic` will call a loop over
#    1911         # `_eval_derivative`:
# -> 1912         return expr._eval_derivative_n_times(v, count)
#    1913
#    1914
#
# d:\ProgramData\Anaconda3\lib\site-packages\sympy\core\cache.py in wrapper(*args, **kwargs)
#      68         def wrapper(*args, **kwargs):
#      69             try:
# ---> 70                 retval = cfunc(*args, **kwargs)
#      71             except TypeError as e:
#      72                 if not e.args or not e.args[0].startswith('unhashable type:'):
#
# d:\ProgramData\Anaconda3\lib\site-packages\sympy\core\mul.py in _eval_derivative_n_times(self, s, n)
#    1011             from sympy.ntheory.multinomial import multinomial_coefficients_iterator
#    1012             for kvals, c in multinomial_coefficients_iterator(m, n):
# -> 1013                 p = prod([arg.diff((s, k)) for k, arg in zip(kvals, args)])
#    1014                 terms.append(c * p)
#    1015             return Add(*terms)
#
# d:\ProgramData\Anaconda3\lib\site-packages\sympy\core\mul.py in prod(a, start)
#    2104
#    2105     """
# -> 2106     return reduce(operator.mul, a, start)
#    2107
#    2108
#
# d:\ProgramData\Anaconda3\lib\site-packages\sympy\core\decorators.py in _func(self, other)
#     234             if not isinstance(other, expectedcls):
#     235                 return retval
# --> 236             return func(self, other)
#     237
#     238         return _func
#
# d:\ProgramData\Anaconda3\lib\site-packages\sympy\core\decorators.py in binary_op_wrapper(self, other)
#     104                     if f is not None:
#     105                         return f(self)
# --> 106             return func(self, other)
#     107         return binary_op_wrapper
#     108     return priority_decorator
#
# d:\ProgramData\Anaconda3\lib\site-packages\sympy\core\expr.py in __mul__(self, other)
#     210     @call_highest_priority('__rmul__')
#     211     def __mul__(self, other):
# --> 212         return Mul(self, other)
#     213
#     214     @sympify_return([('other', 'Expr')], NotImplemented)
#
# d:\ProgramData\Anaconda3\lib\site-packages\sympy\core\cache.py in wrapper(*args, **kwargs)
#      68         def wrapper(*args, **kwargs):
#      69             try:
# ---> 70                 retval = cfunc(*args, **kwargs)
#      71             except TypeError as e:
#      72                 if not e.args or not e.args[0].startswith('unhashable type:'):
#
# d:\ProgramData\Anaconda3\lib\site-packages\sympy\core\operations.py in __new__(cls, evaluate, _sympify, *args)
#      96             return args[0]
#      97
# ---> 98         c_part, nc_part, order_symbols = cls.flatten(args)
#      99         is_commutative = not nc_part
#     100         obj = cls._from_args(c_part + nc_part, is_commutative)
#
# d:\ProgramData\Anaconda3\lib\site-packages\sympy\core\mul.py in flatten(cls, seq)
#     283                 seq = [a, b]
#     284             assert a is not S.One
# --> 285             if not a.is_zero and a.is_Rational:
#     286                 r, b = b.as_coeff_Mul()
#     287                 if b.is_Add:
#
# d:\ProgramData\Anaconda3\lib\site-packages\sympy\core\assumptions.py in getit(self)
#     481             if self._assumptions is self.default_assumptions:
#     482                 self._assumptions = self.default_assumptions.copy()
# --> 483             return _ask(fact, self)
#     484
#     485     getit.func_name = as_property(fact)
#
# d:\ProgramData\Anaconda3\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     554             continue
#     555         if pk in handler_map:
# --> 556             _ask(pk, obj)
#     557
#     558             # we might have found the value of fact
#
# d:\ProgramData\Anaconda3\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     554             continue
#     555         if pk in handler_map:
# --> 556             _ask(pk, obj)
#     557
#     558             # we might have found the value of fact
#
# d:\ProgramData\Anaconda3\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     554             continue
#     555         if pk in handler_map:
# --> 556             _ask(pk, obj)
#     557
#     558             # we might have found the value of fact
#
# d:\ProgramData\Anaconda3\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     542         pass
#     543     else:
# --> 544         a = evaluate(obj)
#     545         if a is not None:
#     546             assumptions.deduce_all_facts(((fact, a),))
#
# d:\ProgramData\Anaconda3\lib\site-packages\sympy\core\mul.py in _eval_is_odd(self)
#    1603
#    1604     def _eval_is_odd(self):
# -> 1605         is_integer = self.is_integer
#    1606         if is_integer:
#    1607             if self.is_zero:
#
# d:\ProgramData\Anaconda3\lib\site-packages\sympy\core\assumptions.py in getit(self)
#     481             if self._assumptions is self.default_assumptions:
#     482                 self._assumptions = self.default_assumptions.copy()
# --> 483             return _ask(fact, self)
#     484
#     485     getit.func_name = as_property(fact)
#
# d:\ProgramData\Anaconda3\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     554             continue
#     555         if pk in handler_map:
# --> 556             _ask(pk, obj)
#     557
#     558             # we might have found the value of fact
#
# d:\ProgramData\Anaconda3\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     554             continue
#     555         if pk in handler_map:
# --> 556             _ask(pk, obj)
#     557
#     558             # we might have found the value of fact
#
# d:\ProgramData\Anaconda3\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     542         pass
#     543     else:
# --> 544         a = evaluate(obj)
#     545         if a is not None:
#     546             assumptions.deduce_all_facts(((fact, a),))
#
# d:\ProgramData\Anaconda3\lib\site-packages\sympy\core\mul.py in _eval_is_imaginary(self)
#    1484         if z:
#    1485             return False
# -> 1486         if self.is_finite is False:
#    1487             return False
#    1488         elif z is False and self.is_finite is True:
#
# d:\ProgramData\Anaconda3\lib\site-packages\sympy\core\assumptions.py in getit(self)
#     481             if self._assumptions is self.default_assumptions:
#     482                 self._assumptions = self.default_assumptions.copy()
# --> 483             return _ask(fact, self)
#     484
#     485     getit.func_name = as_property(fact)
#
# d:\ProgramData\Anaconda3\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     554             continue
#     555         if pk in handler_map:
# --> 556             _ask(pk, obj)
#     557
#     558             # we might have found the value of fact
#
# d:\ProgramData\Anaconda3\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     554             continue
#     555         if pk in handler_map:
# --> 556             _ask(pk, obj)
#     557
#     558             # we might have found the value of fact
#
# d:\ProgramData\Anaconda3\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     549     # Try assumption's prerequisites
#     550     prereq = list(_assume_rules.prereq[fact])
# --> 551     shuffle(prereq)
#     552     for pk in prereq:
#     553         if pk in assumptions:
#
# d:\ProgramData\Anaconda3\lib\random.py in shuffle(self, x, random)
#     360                 # pick an element in x[:i+1] with which to exchange x[i]
#     361                 j = randbelow(i + 1)
# --> 362                 x[i], x[j] = x[j], x[i]
#     363         else:
#     364             _warn('The *random* parameter to shuffle() has been deprecated\n'
#
# KeyboardInterrupt:
